# %%
pip instalal opencv-python
# Out:
# ...
#      ---------------------------------------- 0.0/61.2 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/61.2 kB ? eta -:--:--
#      ------------------------------- ------ 51.2/61.2 kB 660.6 kB/s eta 0:00:01
#      ------------------------------- ------ 51.2/61.2 kB 660.6 kB/s eta 0:00:01
#      -------------------------------------- 61.2/61.2 kB 407.8 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/38.6 MB ? eta -:--:--
#    ---------------------------------------- 0.1/38.6 MB 4.1 MB/s eta 0:00:10
#    ---------------------------------------- 0.2/38.6 MB 3.5 MB/s eta 0:00:12
#    ---------------------------------------- 0.5/38.6 MB 3.8 MB/s eta 0:00:11
#     --------------------------------------- 0.7/38.6 MB 4.2 MB/s eta 0:00:09
#     --------------------------------------- 1.0/38.6 MB 4.3 MB/s eta 0:00:09
#    - -------------------------------------- 1.2/38.6 MB 4.3 MB/s eta 0:00:09
# ...

# %%
import cv2

# %%
import numpy as np

# %%
im1=cv2.imread("C:/Users/admin/Pictures/cv/download.jpg",0)

# %%
im1
# Out:
# array([[ 6,  9, 15, ..., 33, 17,  7],
#        [12, 14, 17, ..., 36, 36, 34],
#        [42, 40, 36, ..., 12, 20, 14],
#        ...,
#        [22, 28,  7, ..., 43, 26, 31],
#        [24, 25, 21, ..., 38, 21, 28],
#        [25, 20, 37, ..., 35, 18, 27]], dtype=uint8)

# %%
cv2.imshow("w1",im1)
cv2.waitKey(10)
cv2.destroyAllWindows
# Out:
# <function destroyAllWindows>

# %%
cv2.imwrite("C:/Users/admin/Pictures/cv/greyhole.jpg",1)
# Out:
# True
